# %% [raw]
# mlpiper()
#
#
#
# %matplotlib inline
#
# from parallelm.mlops import mlops
#
#
# mlops.init()
# mlops.set_stat("tt", 11)

# %% [markdown]
# # Component: String Src
# ## Parameters
# - value: 22222

# %%
from matplotlib import pyplot as plt
import pandas as pd

s = pd.Series([1,2,3], index=['a','b','c'])

s.plot.bar(figsize=(20,10))
plt.xlabel('Foo')
plt.ylabel('Bar')
plt.title("Hello Wolrd");

# %%
s.plot.bar(figsize=(20,10))
plt.xlabel('Foo')
plt.ylabel('Bar')
plt.title("Hello Wolr2");
